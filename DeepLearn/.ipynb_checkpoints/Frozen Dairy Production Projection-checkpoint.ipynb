# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df =pd.read_csv('../../../FINAL-TF2-FILES/TF_2_Notebooks_and_Data/DATA/Frozen_Dessert_Production.csv',
                index_col='DATE',parse_dates=True)

# %%
df
# Out:
#             IPN31152N
# DATE
# 1972-01-01    59.9622
# 1972-02-01    67.0605
# 1972-03-01    74.2350
# 1972-04-01    78.1120
# 1972-05-01    84.7636
# ...               ...
# 2019-05-01   114.5613
# 2019-06-01   124.9605
# 2019-07-01   110.2632
# 2019-08-01   102.6085
# 2019-09-01   101.5866
#
# [573 rows x 1 columns]

# %%
df.columns=['Production']

# %%
df.plot(figsize=(12,8))

# %%
len(df)
# Out:
# 573

# %%
test_size= 18 #24
test_ind =len(df) - test_size

# %%
train = df.iloc[:test_ind]
test = df.iloc[test_ind:]

# %%
len(test)
# Out:
# 18

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler =MinMaxScaler()

# %%
scaler.fit(train)
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
scaled_train=scaler.transform(train)
scaled_test=scaler.transform(test)

# %%
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %%
length = 12 #18
n_features = 1
generator = TimeseriesGenerator(scaled_train,scaled_train,length=length,batch_size=1)

# %%
generator[0]
# Out:
# (array([[[0.00947104],
#          [0.06108982],
#          [0.11326273],
#          [0.14145625],
#          [0.18982663],
#          [0.30495972],
#          [0.30154406],
#          [0.27416065],
#          [0.19736841],
#          [0.08532665],
#          [0.01561588],
#          [0.        ]]]), array([[0.01774221]]))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM,Dense

# %%
model = Sequential()
model.add(LSTM(150,input_shape=(length,n_features)))
model.add(Dense(1))
model.compile(optimizer='adam',loss='mse')
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm_2 (LSTM)                (None, 150)               91200
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 151
# ...
# Total params: 91,351
# Trainable params: 91,351
# Non-trainable params: 0
# _________________________________________________________________

# %%
validation_generator=TimeseriesGenerator(scaled_test,scaled_test,length=length,batch_size=1)

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
early_stop = EarlyStopping(monitor='val_loss',patience=2)

# %%
model.fit_generator(generator,epochs=20,
                    validation_data=validation_generator,callbacks=[early_stop])
# Out:
# Epoch 1/20
# 543/543 [==============================] - 57s 104ms/step - loss: 0.0227 - val_loss: 0.0039
# Epoch 2/20
# 543/543 [==============================] - 55s 102ms/step - loss: 0.0042 - val_loss: 0.0023
# Epoch 3/20
# 543/543 [==============================] - 64s 117ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 4/20
# 543/543 [==============================] - 56s 103ms/step - loss: 0.0035 - val_loss: 0.0034

# %%
losses=pd.DataFrame(model.history.history)

# %%
losses.plot()

# %%
test_prediction =[]
# last 24 timestamps of training data
first_eval_batch = scaled_train[-length:]
# reshape before feeding into network for prediction
current_batch = first_eval_batch.reshape(1,length,n_features)

for i in range (len(test)):
    # get predicition 1 timestamp ahead..[0] is subscripting for just prediction value in returned predict object
    current_pred = model.predict(current_batch)[0]
    # append current prediction
    test_prediction.append(current_pred)
    # update batch to include current prediction and drop the first value thus 
    #moving current batch one step into the future
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)

# %%
test_prediction
# Out:
# [array([0.43365443], dtype=float32),
#  array([0.48726207], dtype=float32),
#  array([0.51859343], dtype=float32),
#  array([0.5041846], dtype=float32),
#  array([0.44238544], dtype=float32),
#  array([0.33093718], dtype=float32),
#  array([0.2099595], dtype=float32),
#  array([0.11670496], dtype=float32),
#  array([0.09581757], dtype=float32),
#  array([0.1415835], dtype=float32),
#  array([0.2280628], dtype=float32),
#  array([0.3265275], dtype=float32),
#  array([0.424021], dtype=float32),
#  array([0.5044734], dtype=float32),
#  array([0.55584776], dtype=float32),
#  array([0.56206757], dtype=float32),
#  array([0.50686413], dtype=float32),
#  array([0.38551298], dtype=float32)]

# %%
true_predictions=scaler.inverse_transform(test_prediction)

# %%
test['Predictions']=true_predictions
# Out:
# /root/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
test.plot()

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(test['Production'],test['Predictions'])#786.381180326942
# Out:
# 143.45986786198512

# %%
np.sqrt(mean_squared_error(test['Production'],test['Predictions']))#28.042488839739992
# Out:
# 11.97747335050198

# %%
#off by an avg of 11 (formerly 28) units of production... better ..
#still missig spikes...play around with parameters to see
